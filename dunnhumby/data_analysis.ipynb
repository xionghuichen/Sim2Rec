# %%
import csv
import pandas as pd

# %%
merged_data = pd.read_csv('data/processed/merged_data.csv')

# %%
#norm_feature_list = ['UNITS', 'PRICE', 'BASE_PRICE']
norm_feature_list = ['STORE_NUM', 'UPC', 'UNITS', 'PRICE', 'BASE_PRICE', 'STORE_ID', 'MSA_CODE', 'SALES_AREA_SIZE_NUM', 'AVG_WEEKLY_BASKETS']

# %%
merged_data.columns.values.tolist()
# Out:
# ['Unnamed: 0',
#  'WEEK_END_DATE',
#  'STORE_NUM',
#  'UPC',
#  'UNITS',
#  'VISITS',
#  'HHS',
#  'SPEND',
#  'PRICE',
#  'BASE_PRICE',
#  'FEATURE',
#  'DISPLAY',
#  'TPR_ONLY',
#  'DESCRIPTION',
#  'MANUFACTURER',
#  'CATEGORY',
#  'SUB_CATEGORY',
#  'PRODUCT_SIZE',
#  'STORE_ID',
#  'STORE_NAME',
#  'ADDRESS_CITY_NAME',
#  'ADDRESS_STATE_PROV_CODE',
#  'MSA_CODE',
#  'SEG_VALUE_NAME',
#  'PARKING_SPACE_QTY',
#  'SALES_AREA_SIZE_NUM',
#  'AVG_WEEKLY_BASKETS']

# %%
merged_feature_list = ['WEEK_END_DATE',
 'STORE_NUM',
 'UPC',
 'UNITS',
 'VISITS',
 'HHS',
 'SPEND',
 'PRICE',
 'BASE_PRICE',
 'FEATURE',
 'DISPLAY',
 'TPR_ONLY',
 'DESCRIPTION',
 'MANUFACTURER',
 'CATEGORY',
 'SUB_CATEGORY',
 'PRODUCT_SIZE',
 'STORE_ID',
 'STORE_NAME',
 'ADDRESS_CITY_NAME',
 'ADDRESS_STATE_PROV_CODE',
 'MSA_CODE',
 'SEG_VALUE_NAME',
 'SALES_AREA_SIZE_NUM',
 'AVG_WEEKLY_BASKETS']

# %%
merged_data = merged_data[merged_feature_list]

# %%
merged_data
# Out:
#        WEEK_END_DATE  STORE_NUM          UPC  UNITS  VISITS  HHS   SPEND  \
# 0         2009-01-14        367   1111009477     13      13   13   18.07
# 1         2009-01-14        367   1111009497     20      18   18   27.80
# 2         2009-01-14        367   1111009507     14      14   14   19.32
# 3         2009-01-14        367   1111035398      4       3    3   14.00
# 4         2009-01-14        367   1111038078      3       3    3    7.50
# ...              ...        ...          ...    ...     ...  ...     ...
# 524945    2012-01-04      29159  31254742735      1       1    1    4.97
# 524946    2012-01-04      29159  31254742835      5       5    5   24.85
# 524947    2012-01-04      29159  88491201426     32      29   23  105.92
# 524948    2012-01-04      29159  88491201427     30      26   23   99.30
# 524949    2012-01-04      29159  88491212971     20      20   20   44.40
#
#         PRICE  BASE_PRICE  FEATURE  ...              SUB_CATEGORY  \
# ...

# %%
merged_data[merged_data['STORE_NUM']==2277]
# Out:
#        WEEK_END_DATE  STORE_NUM          UPC  UNITS  VISITS  HHS   SPEND  \
# 209       2009-01-14       2277   1111009477    158     140  135  218.04
# 210       2009-01-14       2277   1111009497    179     161  157  247.02
# 211       2009-01-14       2277   1111009507     35      34   34   48.30
# 212       2009-01-14       2277   1111035398      9       8    8   31.14
# 213       2009-01-14       2277   1111038078     12      12   12   31.08
# ...              ...        ...          ...    ...     ...  ...     ...
# 521885    2012-01-04       2277  31254742735     11      11   11   54.67
# 521886    2012-01-04       2277  31254742835     15      14   14   74.55
# 521887    2012-01-04       2277  88491201426     21      19   19   70.77
# 521888    2012-01-04       2277  88491201427     13      12   12   43.81
# 521889    2012-01-04       2277  88491212971     68      61   60  136.68
#
#         PRICE  BASE_PRICE  FEATURE  ...              SUB_CATEGORY  \
# ...

# %%
from sklearn import preprocessing

# %%
zscore = preprocessing.StandardScaler()

# %%
merged_data['PRICE'] = zscore.fit_transform(merged_data['PRICE'].values.reshape(-1,1))

# %%
merged_data['PRICE']
# Out:
# 0        -1.277606
# 1        -1.277606
# 2        -1.284020
# 3         0.075563
# 4        -0.565749
#             ...
# 524945    1.018293
# 524946    1.018293
# 524947   -0.046286
# 524948   -0.046286
# 524949   -0.745317
# Name: PRICE, Length: 524950, dtype: float64

# %%
merged_data
# Out:
#        WEEK_END_DATE  STORE_NUM          UPC  UNITS  VISITS  HHS   SPEND  \
# 0         2009-01-14        367   1111009477     13      13   13   18.07
# 1         2009-01-14        367   1111009497     20      18   18   27.80
# 2         2009-01-14        367   1111009507     14      14   14   19.32
# 3         2009-01-14        367   1111035398      4       3    3   14.00
# 4         2009-01-14        367   1111038078      3       3    3    7.50
# ...              ...        ...          ...    ...     ...  ...     ...
# 524945    2012-01-04      29159  31254742735      1       1    1    4.97
# 524946    2012-01-04      29159  31254742835      5       5    5   24.85
# 524947    2012-01-04      29159  88491201426     32      29   23  105.92
# 524948    2012-01-04      29159  88491201427     30      26   23   99.30
# 524949    2012-01-04      29159  88491212971     20      20   20   44.40
#
#            PRICE  BASE_PRICE  FEATURE  ...              SUB_CATEGORY  \
# ...

# %%
for feature in norm_feature_list:
    merged_data[feature] = zscore.fit_transform(merged_data[feature].values.reshape(-1,1))

# %%
merged_data
# Out:
#        WEEK_END_DATE  STORE_NUM       UPC     UNITS  VISITS  HHS   SPEND  \
# 0         2009-01-14  -1.610890 -0.442202 -0.220760      13   13   18.07
# 1         2009-01-14  -1.610890 -0.442202  0.013087      18   18   27.80
# 2         2009-01-14  -1.610890 -0.442202 -0.187353      14   14   19.32
# 3         2009-01-14  -1.610890 -0.442201 -0.521420       3    3   14.00
# 4         2009-01-14  -1.610890 -0.442201 -0.554826       3    3    7.50
# ...              ...        ...       ...       ...     ...  ...     ...
# 524945    2012-01-04   1.627287  1.005835 -0.621640       1    1    4.97
# 524946    2012-01-04   1.627287  1.005835 -0.488013       5    5   24.85
# 524947    2012-01-04   1.627287  3.755346  0.413967      29   23  105.92
# 524948    2012-01-04   1.627287  3.755346  0.347153      26   23   99.30
# 524949    2012-01-04   1.627287  3.755346  0.013087      20   20   44.40
#
#            PRICE  BASE_PRICE  FEATURE  ...              SUB_CATEGORY  \
# ...

# %%
feature_list = ['WEEK_END_DATE', 'FEATURE', 'DISPLAY', 'TPR_ONLY', 'STORE_NUM', 'UPC', 'UNITS', 'PRICE', 'BASE_PRICE', 'STORE_ID', 'MSA_CODE', 'SALES_AREA_SIZE_NUM', 'AVG_WEEKLY_BASKETS']

# %%
merged_data[feature_list]
# Out:
#        WEEK_END_DATE  FEATURE  DISPLAY  TPR_ONLY  STORE_NUM       UPC  \
# 0         2009-01-14        0        0         1  -1.610890 -0.442202
# 1         2009-01-14        0        0         0  -1.610890 -0.442202
# 2         2009-01-14        0        0         0  -1.610890 -0.442202
# 3         2009-01-14        0        0         1  -1.610890 -0.442201
# 4         2009-01-14        0        0         0  -1.610890 -0.442201
# ...              ...      ...      ...       ...        ...       ...
# 524945    2012-01-04        0        0         0   1.627287  1.005835
# 524946    2012-01-04        0        0         0   1.627287  1.005835
# 524947    2012-01-04        0        0         0   1.627287  3.755346
# 524948    2012-01-04        0        0         0   1.627287  3.755346
# 524949    2012-01-04        0        0         1   1.627287  3.755346
#
#            UNITS     PRICE  BASE_PRICE  STORE_ID  MSA_CODE  \
# 0      -0.220760 -1.277606   -1.245766 -1.610890 -0.645367
# ...

# %%
merged_data
# Out:
#        WEEK_END_DATE  STORE_NUM       UPC     UNITS  VISITS  HHS   SPEND  \
# 0         2009-01-14  -1.610890 -0.442202 -0.220760      13   13   18.07
# 1         2009-01-14  -1.610890 -0.442202  0.013087      18   18   27.80
# 2         2009-01-14  -1.610890 -0.442202 -0.187353      14   14   19.32
# 3         2009-01-14  -1.610890 -0.442201 -0.521420       3    3   14.00
# 4         2009-01-14  -1.610890 -0.442201 -0.554826       3    3    7.50
# ...              ...        ...       ...       ...     ...  ...     ...
# 524945    2012-01-04   1.627287  1.005835 -0.621640       1    1    4.97
# 524946    2012-01-04   1.627287  1.005835 -0.488013       5    5   24.85
# 524947    2012-01-04   1.627287  3.755346  0.413967      29   23  105.92
# 524948    2012-01-04   1.627287  3.755346  0.347153      26   23   99.30
# 524949    2012-01-04   1.627287  3.755346  0.013087      20   20   44.40
#
#            PRICE  BASE_PRICE  FEATURE  ...              SUB_CATEGORY  \
# ...

# %%
merged_data.to_csv('data/processed/merged_data_norm_1017.csv')

# %%
merged_data = pd.read_csv('data/processed/merged_data_norm_1017.csv')

# %%
merged_data[:10]
# Out:
#    Unnamed: 0 WEEK_END_DATE  STORE_NUM       UPC     UNITS  VISITS  HHS  \
# 0           0    2009-01-14   -1.61089 -0.442202 -0.220760      13   13
# 1           1    2009-01-14   -1.61089 -0.442202  0.013087      18   18
# 2           2    2009-01-14   -1.61089 -0.442202 -0.187353      14   14
# 3           3    2009-01-14   -1.61089 -0.442201 -0.521420       3    3
# 4           4    2009-01-14   -1.61089 -0.442201 -0.554826       3    3
# 5           5    2009-01-14   -1.61089 -0.442201 -0.588233       2    2
# 6           6    2009-01-14   -1.61089 -0.442198 -0.187353      13   13
# 7           7    2009-01-14   -1.61089 -0.442198  0.313747      26   25
# 8           8    2009-01-14   -1.61089 -0.442198  0.514187      27   25
# 9           9    2009-01-14   -1.61089 -0.442198  1.015287      40   40
#
#     SPEND     PRICE  BASE_PRICE  ...              SUB_CATEGORY  PRODUCT_SIZE  \
# 0   18.07 -1.277606   -1.245766  ...                  PRETZELS         15 OZ
# ...

# %%
len(merged_data)
# Out:
# 524950

# %%
merged_data.dropna(axis=0, how='any')
# Out:
#         Unnamed: 0 WEEK_END_DATE  STORE_NUM       UPC     UNITS  VISITS  HHS  \
# 0                0    2009-01-14  -1.610890 -0.442202 -0.220760      13   13
# 1                1    2009-01-14  -1.610890 -0.442202  0.013087      18   18
# 2                2    2009-01-14  -1.610890 -0.442202 -0.187353      14   14
# 3                3    2009-01-14  -1.610890 -0.442201 -0.521420       3    3
# 4                4    2009-01-14  -1.610890 -0.442201 -0.554826       3    3
# ...            ...           ...        ...       ...       ...     ...  ...
# 524945      524945    2012-01-04   1.627287  1.005835 -0.621640       1    1
# 524946      524946    2012-01-04   1.627287  1.005835 -0.488013       5    5
# 524947      524947    2012-01-04   1.627287  3.755346  0.413967      29   23
# 524948      524948    2012-01-04   1.627287  3.755346  0.347153      26   23
# 524949      524949    2012-01-04   1.627287  3.755346  0.013087      20   20
#
# ...

# %%
len(merged_data)
# Out:
# 524950

# %%
merged_data = merged_data.dropna(axis=0, how='any')

# %%
len(merged_data)
# Out:
# 524742

# %%
merged_data = pd.read_csv('data/processed/merged_data_norm_3.csv')

# %%
merged_data[:20]
# Out:
#     Unnamed: 0 WEEK_END_DATE  STORE_NUM         UPC     UNITS  VISITS  HHS  \
# 0            0    2009-01-14        367  1111009477 -0.220760      13   13
# 1            1    2009-01-14        367  1111009497  0.013087      18   18
# 2            2    2009-01-14        367  1111009507 -0.187353      14   14
# 3            3    2009-01-14        367  1111035398 -0.521420       3    3
# 4            4    2009-01-14        367  1111038078 -0.554826       3    3
# 5            5    2009-01-14        367  1111038080 -0.588233       2    2
# 6            6    2009-01-14        367  1111085319 -0.187353      13   13
# 7            7    2009-01-14        367  1111085345  0.313747      26   25
# 8            8    2009-01-14        367  1111085350  0.514187      27   25
# 9            9    2009-01-14        367  1111087395  1.015287      40   40
# 10          10    2009-01-14        367  1111087396  1.382760      43   42
# ...

# %%
len(merged_data)
# Out:
# 524950

# %%
merged_data = merged_data.dropna(axis=0, how='any')

# %%
merged_data[:10]
# Out:
#    Unnamed: 0 WEEK_END_DATE  STORE_NUM         UPC     UNITS  VISITS  HHS  \
# 0           0    2009-01-14        367  1111009477 -0.220760      13   13
# 1           1    2009-01-14        367  1111009497  0.013087      18   18
# 2           2    2009-01-14        367  1111009507 -0.187353      14   14
# 3           3    2009-01-14        367  1111035398 -0.521420       3    3
# 4           4    2009-01-14        367  1111038078 -0.554826       3    3
# 5           5    2009-01-14        367  1111038080 -0.588233       2    2
# 6           6    2009-01-14        367  1111085319 -0.187353      13   13
# 7           7    2009-01-14        367  1111085345  0.313747      26   25
# 8           8    2009-01-14        367  1111085350  0.514187      27   25
# 9           9    2009-01-14        367  1111087395  1.015287      40   40
#
#     SPEND     PRICE  BASE_PRICE  ...              SUB_CATEGORY  PRODUCT_SIZE  \
# ...

# %%
len(merged_data)
# Out:
# 524742

# %%
merged_data.to_csv('data/processed/merged_data_norm_1022.csv')
